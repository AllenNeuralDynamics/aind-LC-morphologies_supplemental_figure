# %% [markdown]
# ## Things to look at
# Plot histograms of first several branch points<br>
# Plot out path to cortex<br>
# 3d plot highlighting fiber tract segments

# %% [markdown]
# Additional items:
# plot distribution of neuronwise projection correlations - bimodal distribution?
# add dendritic features to correlation plot, i.e. dendritic length, sholl intersection (10 or 20 um)
# plot ap dv soma positions with top projection targets (drop categories with single projector)
